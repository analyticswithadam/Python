# %% [markdown]
# <a href="https://colab.research.google.com/github/analyticswithadam/Python/blob/main/Extract_Comments_from_TrustPilot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from time import sleep
import requests
from google.colab import files
import pandas as pd
from bs4 import BeautifulSoup

def soup2list(src, list_, attr=None):
    if attr:
        for val in src:
            list_.append(val[attr])
    else:
        for val in src:
            list_.append(val.get_text())

users = []
#userReviewNum = []
ratings = []
locations = []
dates = []
reviews = []

from_page = 1
to_page = 10
company = 'guineys.ie'

for i in range(from_page, to_page+1):

   result = requests.get(fr"https://www.trustpilot.com/review/{company}?page={i}")
   soup = BeautifulSoup(result.content)

   # Trust Pilot was setup in a way that's not friendly to scraping, so this hacky method will do.
   soup2list(soup.find_all('span', {'class','typography_heading-xxs__QKBS8 typography_appearance-default__AAY17'}), users)
   soup2list(soup.find_all('div', {'class','typography_body-m__xgxZ_ typography_appearance-subtle__8_H2l styles_detailsIcon__Fo_ua'}), locations)
   #soup2list(soup.find_all('span', {'class','typography_body-m__xgxZ_ typography_appearance-subtle__8_H2l'}), userReviewNum)
   soup2list(soup.find_all('div', {'class','styles_reviewHeader__iU9Px'}), dates)
   soup2list(soup.find_all('div', {'class','styles_reviewHeader__iU9Px'}), ratings, attr='data-service-review-rating')
   soup2list(soup.find_all('div', {'class','styles_reviewContent__0Q2Tg'}), reviews)

   # To avoid throttling
   sleep(1)



review_data = pd.DataFrame(
{
   'Username':users,
   #'Total reviews':userReviewNum,
   'location':locations,
   'date':dates,
   'content':reviews,
   'Rating': ratings
})

# %%
review_data
# Out:
#               Username location                  date  \
# 0         Anna Mcmanus       IE    5 days agoVerified
# 1         Marie Quirke       IE  Jun 29, 2024Verified
# 2      Margaret Murphy       IE    5 days agoVerified
# 3                 Kate       IE    7 days agoVerified
# 4          Mary Clarke       GB  Jun 27, 2024Verified
# ..                 ...      ...                   ...
# 195           R Stokes       IE  May 22, 2024Verified
# 196              Guest       IE  May 30, 2024Verified
# 197     Kathleen Burke       IE  May 23, 2024Verified
# 198          Happymum        IE  May 21, 2024Verified
# 199  Ms Aisling Cahill       IE  May 27, 2024Verified
#
#                                                content Rating
# 0    Received my DuveReceived my Duvet sets 2 days ...      5
# 1    Ordered my item late on Friday eveningOrdered ...      5
# 2    Bought two pairs of shoes fory MumBought two p...      5
# 3    Do not accept returnsDo not accept returns, op...      1
# 4    I have shopped with Guineys for over 50 years....      5
# ..                                                 ...    ...
# 195  Great delivery serviceDate of experience: May ...      5
# 196  Fast DeliveryFast DeliveryDate of experience: ...      5
# 197  Fast deliveryFast delivery Date of experience:...      5
# 198     Fast delivery Date of experience: May 13, 2024      5
# 199  Fast deliveryFast delivery Date of experience:...      4
#
# [200 rows x 5 columns]

# %%
# Convert the DataFrame to a CSV file and download it
review_data.to_csv('reviews.csv', index=False)
files.download('reviews.csv')
