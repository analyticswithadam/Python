# %% [markdown]
# <a href="https://colab.research.google.com/github/analyticswithadam/Python/blob/main/Web_Scraping_from_TrustPilot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from time import sleep
import requests

import pandas as pd
from bs4 import BeautifulSoup

def soup2list(src, list_, attr=None):
    if attr:
        for val in src:
            list_.append(val[attr])
    else:
        for val in src:
            list_.append(val.get_text())

users = []
userReviewNum = []
ratings = []
locations = []
dates = []
reviews = []

from_page = 1
to_page = 60
company = 'eshakti.com'

for i in range(from_page, to_page+1):

   result = requests.get(fr"https://www.trustpilot.com/review/{company}?page={i}")
   soup = BeautifulSoup(result.content)

   # Trust Pilot was setup in a way that's not friendly to scraping, so this hacky method will do.
   soup2list(soup.find_all('span', {'class','typography_heading-xxs__QKBS8 typography_appearance-default__AAY17'}), users)
   soup2list(soup.find_all('div', {'class','typography_body-m__xgxZ_ typography_appearance-subtle__8_H2l styles_detailsIcon__Fo_ua'}), locations)
   soup2list(soup.find_all('span', {'class','typography_body-m__xgxZ_ typography_appearance-subtle__8_H2l'}), userReviewNum)
   soup2list(soup.find_all('div', {'class','styles_reviewHeader__iU9Px'}), dates)
   soup2list(soup.find_all('div', {'class','styles_reviewHeader__iU9Px'}), ratings, attr='data-service-review-rating')
   soup2list(soup.find_all('div', {'class','styles_reviewContent__0Q2Tg'}), reviews)

   # To avoid throttling
   sleep(1)

review_data = pd.DataFrame(
{
   'Username':users,
   'Total reviews':userReviewNum,
   'location':locations,
   'date':dates,
   'content':reviews,
   'Rating': ratings
})

# %%
review_data
# Out:
#             Username Total reviews location          date  \
# 0     Jessica Lebitz     3 reviews       DE    7 days ago
# 1       Karen Kellam      1 review       US    6 days ago
# 2                 Su      1 review       AU  Nov 28, 2023
# 3      SLPA Jennings     2 reviews       US     A day ago
# 4         Kaitlyne H      1 review       CA    5 days ago
# ...              ...           ...      ...           ...
# 1195  Ellen Jacobson      1 review       US  Jan 11, 2021
# 1196            Foxy      1 review       US   Jan 5, 2021
# 1197  Maggie Roberts     2 reviews       US  Dec 28, 2020
# 1198      Leah Hogan      1 review       US  Dec 23, 2020
# 1199   Annalakshmi S      1 review       US  Dec 15, 2020
#
#                                                 content Rating
# 0     Sizing wrong and takes forever to arriveIt too...      3
# 1     Love the Clothes, Hate the ServiceI am a Privi...      2
# 2     Good quality dresses, arrive ridiculously late...      3
# 3     Very sketchyI was excited to try eShakti after...      1
# 4     Don't give them your $ or trustLike many other...      1
# ...                                                 ...    ...
# 1195  Quality ClothingMy dress is well constructed a...      5
# 1196  Excellent!I ordered two dresses and a skirt! T...      5
# 1197  Beautiful quality; great serviceBeautiful, wel...      5
# 1198  Love this companyLove this company, great cust...      4
# 1199  Impeccable!Dear eShakti Team,Thank you so much...      5
#
# [1200 rows x 6 columns]
