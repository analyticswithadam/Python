# %% [markdown]
# <a href="https://colab.research.google.com/github/analyticswithadam/Python/blob/main/YouTube_Comments_Advanced.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
dev = "INSERT API KEY HERE"

# %% [markdown]
# ## Pull All Comments

# %%
import googleapiclient.discovery
import pandas as pd

api_service_name = "youtube"
api_version = "v3"
DEVELOPER_KEY = dev

youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey=DEVELOPER_KEY)

request = youtube.commentThreads().list(
    part="snippet",
    videoId="-GJgqIJsTME",
    maxResults=100
)

comments = []

# Execute the request.
response = request.execute()

# Get the comments from the response.
for item in response['items']:
    comment = item['snippet']['topLevelComment']['snippet']
    public = item['snippet']['isPublic']
    comments.append([
        comment['authorDisplayName'],
        comment['publishedAt'],
        comment['likeCount'],
        comment['textOriginal'],
        public
    ])

while (1 == 1):
  try:
   nextPageToken = response['nextPageToken']
  except KeyError:
   break
  nextPageToken = response['nextPageToken']
  # Create a new request object with the next page token.
  nextRequest = youtube.commentThreads().list(part="snippet", videoId="-GJgqIJsTME", maxResults=100, pageToken=nextPageToken)
  # Execute the next request.
  response = nextRequest.execute()
  # Get the comments from the next response.
  for item in response['items']:
    comment = item['snippet']['topLevelComment']['snippet']
    public = item['snippet']['isPublic']
    comments.append([
        comment['authorDisplayName'],
        comment['publishedAt'],
        comment['likeCount'],
        comment['textOriginal'],
        public
    ])

df = pd.DataFrame(comments, columns=['author', 'updated_at', 'like_count', 'text','public'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 554 entries, 0 to 553
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   author      554 non-null    object
#  1   updated_at  554 non-null    object
#  2   like_count  554 non-null    int64
#  3   text        554 non-null    object
#  4   public      554 non-null    bool
# dtypes: bool(1), int64(1), object(3)
# memory usage: 18.0+ KB

# %%
response['items'][0]
# Out:
# {'kind': 'youtube#commentThread',
#  'etag': '0Y09kiMXu0KDRMktsTeGD8ADOnI',
#  'id': 'Ugw2vgR8j1kd9DdbpCJ4AaABAg',
#  'snippet': {'channelId': 'UC2utQmYluWGlhV-W0rTA2wg',
#   'videoId': '-GJgqIJsTME',
#   'topLevelComment': {'kind': 'youtube#comment',
#    'etag': 'fDL33cb616TBnX1qrlubHuFZM10',
#    'id': 'Ugw2vgR8j1kd9DdbpCJ4AaABAg',
#    'snippet': {'channelId': 'UC2utQmYluWGlhV-W0rTA2wg',
#     'videoId': '-GJgqIJsTME',
#     'textDisplay': 'dope episode but I couldn&#39;t stop focusing at your boys bottom row of teeth &amp; joker laugh 🥴',
#     'textOriginal': "dope episode but I couldn't stop focusing at your boys bottom row of teeth & joker laugh 🥴",
#     'authorDisplayName': 'Daniel Santiago',
#     'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/APkrFKZ-tI79EEzqAu1V6usYoEgw3ntLLBXMVv2qJuew5uwSlVIpUVHJAsJbFG8P155O=s48-c-k-c0x00ffffff-no-rj',
#     'authorChannelUrl': 'http://www.youtube.com/channel/UCgbc-l0WUxJe6vXSJhN9nhQ',
#     'authorChannelId': {'value': 'UCgbc-l0WUxJe6vXSJhN9nhQ'},
#     'canRate': True,
#     'viewerRating': 'none',
#     'likeCount': 0,
#     'publishedAt': '2023-10-23T15:47:05Z',
#     'updatedAt': '2023-10-23T15:47:05Z'}},
#   'canReply': True,
#   'totalReplyCount': 0,
#   'isPublic': True}}

# %%
df.head(10)
# Out:
#                  author            updated_at  like_count  \
# 0        Action Bronson  2023-10-23T17:53:02Z         400
# 1  Daffers Little-Jones  2023-10-27T11:14:45Z           0
# 2                 RyanK  2023-10-27T09:55:16Z           0
# 3         SnowMonkey AR  2023-10-27T09:49:56Z           0
# 4             Michael l  2023-10-27T09:21:01Z           0
# 5           Jacob Moore  2023-10-27T09:03:25Z           0
# 6                vntgzl  2023-10-27T08:56:02Z           0
# 7            J Williams  2023-10-27T07:20:23Z           1
# 8          Victor Venet  2023-10-27T05:46:57Z           0
# 9                 Ian V  2023-10-27T05:31:02Z           0
#
#                                                 text  public
# 0                                  PARIS. WITH LOVE.    True
# 1                    Best sequel since Terminator 2.    True
# 2                                      Clovis lives!    True
# 3  See, this is how you should visit Paris. Local...    True
# 4  Het Bourgondische leven zoals het bedoeld is.k...    True
# 5  Clovis + Action in Paris is and always wil be ...    True
# 6        PLEASE GO TO EVERY COUNTRY FOR THIS SERIES😩    True
# 7  nothing more authentic than a polish dude cook...    True
# 8  Something happend when those two guys are toge...    True
# 9  I’ve been waiting for this for so long, God is...    True

# %% [markdown]
# ## Sort by Likes and Get Top 10

# %%
df.sort_values(by='like_count', ascending=False)[0:10]
# Out:
#                            author            updated_at  like_count  \
# 319                        Adrian  2022-05-31T19:35:45Z         246
# 254                 Saul Espinoza  2022-06-09T00:28:08Z          59
# 352                   Vickar Khan  2022-05-30T19:58:27Z          50
# 438                      Zaafir C  2022-06-30T11:40:50Z          46
# 422  Alexis Antonio Gonzalez Haro  2022-06-30T15:07:46Z          37
# 310           Adam Szekely-Nemeth  2022-07-06T11:22:44Z          31
# 90                    Dilip Saini  2023-09-13T11:08:33Z          29
# 312                        Joseph  2022-06-01T08:53:02Z          20
# 0                 How to Power BI  2022-10-10T10:02:51Z          15
# 85                 Charlie Mather  2023-09-13T12:28:13Z          13
#
#                                                   text     video_id  public
# 319  This is probably the best PBI visualization vi...  Lfzu74XDyco    True
# 254  7:08 area charts!\n7:54 data labels\n9:40 cust...  Lfzu74XDyco    True
# 352  Amazing content. there was so much more that y...  Lfzu74XDyco    True
# 438  You are killing it with these videos.\nThis da...  cYwioeHu_OU    True
# 422  Dude, I would like to see more videos like thi...  cYwioeHu_OU    True
# 310  Definitely would like to see more videos aroun...  cYwioeHu_OU    True
# 90   I just love this guys with all the out of box ...  TiS6vnju_mI    True
# 312  This is actually really amazing. As a new rece...  Lfzu74XDyco    True
# 0    If you are interested in taking your Power BI ...  cYwioeHu_OU    True
# 85   Beautiful solution!! One concern is that the m...  TiS6vnju_mI    True

# %% [markdown]
# #Pull all Comments for Multiple Videos

# %% [markdown]
# ## 1. Get Comments Function

# %%
import googleapiclient.discovery
import pandas as pd

api_service_name = "youtube"
api_version = "v3"
DEVELOPER_KEY = dev

youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey=DEVELOPER_KEY)


def getcomments(video):
  request = youtube.commentThreads().list(
      part="snippet",
      videoId=video,
      maxResults=100
  )

  comments = []

  # Execute the request.
  response = request.execute()

  # Get the comments from the response.
  for item in response['items']:
      comment = item['snippet']['topLevelComment']['snippet']
      public = item['snippet']['isPublic']
      comments.append([
          comment['authorDisplayName'],
          comment['publishedAt'],
          comment['likeCount'],
          comment['textOriginal'],
          comment['videoId'],
          public
      ])

  while (1 == 1):
    try:
     nextPageToken = response['nextPageToken']
    except KeyError:
     break
    nextPageToken = response['nextPageToken']
    # Create a new request object with the next page token.
    nextRequest = youtube.commentThreads().list(part="snippet", videoId=video, maxResults=100, pageToken=nextPageToken)
    # Execute the next request.
    response = nextRequest.execute()
    # Get the comments from the next response.
    for item in response['items']:
      comment = item['snippet']['topLevelComment']['snippet']
      public = item['snippet']['isPublic']
      comments.append([
          comment['authorDisplayName'],
          comment['publishedAt'],
          comment['likeCount'],
          comment['textOriginal'],
          comment['videoId'],
          public
      ])

  df2 = pd.DataFrame(comments, columns=['author', 'updated_at', 'like_count', 'text','video_id','public'])
  return df2

# %%
df = getcomments('TYxqBTdOq24')
df
# Out:
#                 author            updated_at  like_count  \
# 0               yaohun  2023-09-08T05:43:51Z           0
# 1       Cedric Goodwin  2023-06-08T07:21:41Z           0
# 2  Analytics with Adam  2023-05-10T06:12:50Z           1
#
#                                                 text     video_id  public
# 0  Hi, sorry I am very new to SAP dashboard and h...  TYxqBTdOq24    True
# 1                                         ⭐ Promo_SM  TYxqBTdOq24    True
# 2  Interested in thoughts on SAC compared with Po...  TYxqBTdOq24    True

# %% [markdown]
# ## 2. For Loop for List of IDs

# %%
df = pd.DataFrame()
for i in ['QOcP5OvSwlI','Lfzu74XDyco','TiS6vnju_mI','cYwioeHu_OU']:
  df2 = getcomments(i)
  df = pd.concat([df, df2])

# %%
df
# Out:
#                  author            updated_at  like_count  \
# 0        Artur Nawrocki  2023-10-27T06:28:00Z           0
# 1        Bostjan Brumec  2023-10-27T06:23:00Z           0
# 2       Esteban Herrera  2023-10-27T04:12:19Z           0
# 3                Jyothi  2023-10-27T02:07:35Z           0
# 4            Anil Ameer  2023-10-26T19:42:54Z           0
# ..                  ...                   ...         ...
# 440  sameer vishwakarma  2022-06-30T11:17:57Z           0
# 441       Adam Sikorski  2022-06-30T11:13:33Z           0
# 442  Unq.Universalfacts  2022-06-30T11:09:16Z           0
# 443         Ahmed Tareq  2022-06-30T11:04:25Z           0
# 444     Jonathan CHANAL  2022-06-30T11:03:35Z           0
#
#                                                   text     video_id  public
# 0    SVG visuals has taken LinkedIn by storm. Too l...  QOcP5OvSwlI    True
# 1    Very inspiring! Maybe it can be used to create...  QOcP5OvSwlI    True
# 2                                   As always excelent  QOcP5OvSwlI    True
# 3    Thanks Bas, for the video. Could you kindly te...  QOcP5OvSwlI    True
# 4    Take notes 📝  Microsoft, you are not listening...  QOcP5OvSwlI    True
# ..                                                 ...          ...     ...
# 440                                               Cool  cYwioeHu_OU    True
# 441                                 Ok that looks dope  cYwioeHu_OU    True
# 442  Amazing.. Thanks a lot .. Can you plz share da...  cYwioeHu_OU    True
# 443                                                  🤩  cYwioeHu_OU    True
# 444                    Realy nice design! well done ;)  cYwioeHu_OU    True
#
# [966 rows x 6 columns]

# %%
df['video_id'].value_counts()
# Out:
# cYwioeHu_OU    445
# Lfzu74XDyco    371
# TiS6vnju_mI    100
# QOcP5OvSwlI     50
# Name: video_id, dtype: int64
