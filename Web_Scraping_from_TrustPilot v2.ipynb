# %% [markdown]
# <a href="https://colab.research.google.com/github/analyticswithadam/Python/blob/main/Web_Scraping_from_TrustPilot%20v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from time import sleep
import requests
from google.colab import files
import pandas as pd
from bs4 import BeautifulSoup

def soup2list(src, list_, attr=None):
    if attr:
        for val in src:
            list_.append(val[attr])
    else:
        for val in src:
            list_.append(val.get_text())

users = []
#userReviewNum = []
ratings = []
locations = []
dates = []
reviews = []

from_page = 1
to_page = 6
company = 'www.pearsonvue.co.uk'

for i in range(from_page, to_page+1):

   result = requests.get(fr"https://www.trustpilot.com/review/{company}?page={i}")
   soup = BeautifulSoup(result.content)

   # Trust Pilot was setup in a way that's not friendly to scraping, so this hacky method will do.
   soup2list(soup.find_all('span', {'class','typography_heading-xxs__QKBS8 typography_appearance-default__AAY17'}), users)
   soup2list(soup.find_all('div', {'class','typography_body-m__xgxZ_ typography_appearance-subtle__8_H2l styles_detailsIcon__Fo_ua'}), locations)
   #soup2list(soup.find_all('span', {'class','typography_body-m__xgxZ_ typography_appearance-subtle__8_H2l'}), userReviewNum)
   soup2list(soup.find_all('div', {'class','styles_reviewHeader__iU9Px'}), dates)
   soup2list(soup.find_all('div', {'class','styles_reviewHeader__iU9Px'}), ratings, attr='data-service-review-rating')
   soup2list(soup.find_all('div', {'class','styles_reviewContent__0Q2Tg'}), reviews)

   # To avoid throttling
   sleep(1)



review_data = pd.DataFrame(
{
   'Username':users,
   #'Total reviews':userReviewNum,
   'location':locations,
   'date':dates,
   'content':reviews,
   'Rating': ratings
})
# Out:
# 120 138 120 120 120

# %%
review_data
# Out:
#                     Username location          date  \
# 0               Alex Schwarz       DE    4 days ago
# 1    Constantine Constantine       GB    4 days ago
# 2                      Amber       CA    6 days ago
# 3                     A. Aza       NL    4 days ago
# 4                     Taylor       US  Apr 29, 2024
# ..                       ...      ...           ...
# 115           Oscar Madrigal       US   Sep 8, 2023
# 116              Pete Dupree       GB  Sep 30, 2023
# 117          Sanjeev Chauhan       IN  Dec 30, 2023
# 118                     Liam       GB   Feb 5, 2024
# 119                Hakan Car       GB  Oct 25, 2023
#
#                                                content Rating
# 0    suspicion of manipulation of answersWhen takin...      1
# 1    Absolutely Horrendous Experience - A Nightmare...      1
# 2    Complete s***show!!…I am surprised tech giants...      1
# 3    Everything was tested goodEverything was teste...      1
# 4    Online Proctoring - STAY AWAYOnline proctoring...      1
# ..                                                 ...    ...
# 115  Karan from Pearson Vue, a robotic proctorI was...      1
# 116  Don't use themWow, I queued for 90 minutes for...      1
# 117  Horrible experience with Pearson Vue and their...      1
# 118  Pearson awful customer serviceI booked Pearson...      1
# 119  70 alexandra road, manchesterI had my aws saa ...      1
#
# [120 rows x 5 columns]

# %%
# Convert the DataFrame to a CSV file and download it
review_data.to_csv('reviews.csv', index=False)
files.download('reviews.csv')
